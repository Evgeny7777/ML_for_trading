# %%
import os; os.chdir('../')
import sys; sys.path.append('.')

# %%
# %config InlineBackend.figure_format = 'retina'
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 1000)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %config InlineBackend.figure_format = 'retina'
from IPython.core.display import display, HTML, Markdown
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import json
from datetime import datetime, timezone

# %%
from mongoengine.connection import disconnect
from importlib import reload
import py.classes as classes;reload(classes)
import py.mongo as mongo;reload(mongo)
import experiment_analysis.mongo_utils as mu;reload(mu)
disconnect()
db = mongo.connect_to_mongo(db_name='evo_v2')

import logging
l = logging.getLogger("my_logger")
logging.basicConfig(level=logging.DEBUG)
# Out:
# <module 'py.classes' from '/Users/userid/git/evotrade/py/classes.py'>
# <module 'py.mongo' from '/Users/userid/git/evotrade/py/mongo.py'>
# <module 'experiment_analysis.mongo_utils' from '/Users/userid/git/evotrade/experiment_analysis/mongo_utils.py'>

# %% [markdown]
# # V2

# %% [markdown]
# ## 5M

# %% [markdown]
# ### sell

# %%
#SR sell new 5M
dfs, spoints = mu.get_experiment_info('5d0e9affd71f100b8a48f45d')

# %%
mu.add_colors_and_move(dfs[:20])
# Out:
# <style  type="text/css" >
#     #T_a7a16454_ae4b_11e9_9170_784f435f5e05row0_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_a7a16454_ae4b_11e9_9170_784f435f5e05row0_col3 {
#             background-color:  #8e5b5b;
#             color:  #f1f1f1;
#             background-color:  #d5efcf;
#             color:  #000000;
#         }    #T_a7a16454_ae4b_11e9_9170_784f435f5e05row0_col4 {
#             background-color:  #391f1f;
#             color:  #f1f1f1;
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }    #T_a7a16454_ae4b_11e9_9170_784f435f5e05row0_col5 {
#             background-color:  #c27f7e;
#             color:  #000000;
#             background-color:  #a3da9d;
#             color:  #000000;
#         }    #T_a7a16454_ae4b_11e9_9170_784f435f5e05row0_col6 {
#             background-color:  #ffffff;
# ...

# %%
#SR sell 10M
dfs10, spoints10 = mu.get_experiment_info('5d0e9b16d71f100b8a48f460')

# %%
mu.add_colors_and_move(dfs10.reset_index().sort_values(by='vdiff', ascending=False))
# Out:
# <style  type="text/css" >
#     #T_a616e308_a03a_11e9_a615_784f435f5e05row0_col0 {
#             background-color:  #f2f2d7;
#             color:  #000000;
#             background-color:  #067230;
#             color:  #f1f1f1;
#         }    #T_a616e308_a03a_11e9_a615_784f435f5e05row0_col3 {
#             background-color:  #f4f4de;
#             color:  #000000;
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }    #T_a616e308_a03a_11e9_a615_784f435f5e05row0_col4 {
#             background-color:  #c38480;
#             color:  #000000;
#             background-color:  #9fd899;
#             color:  #000000;
#         }    #T_a616e308_a03a_11e9_a615_784f435f5e05row0_col5 {
#             background-color:  #fafaf0;
#             color:  #000000;
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }    #T_a616e308_a03a_11e9_a615_784f435f5e05row0_col6 {
#             background-color:  #9e6666;
# ...

# %% [markdown]
# ### buy

# %%
#SR buy
dfb, spointb = mu.get_experiment_info('5d0e9b05d71f100b8a48f45e')

# %%
mu.add_colors_and_move(dfb[:40])
# Out:
# <style  type="text/css" >
#     #T_f5493588_ae4b_11e9_8512_784f435f5e05row0_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_f5493588_ae4b_11e9_8512_784f435f5e05row0_col3 {
#             background-color:  #825353;
#             color:  #f1f1f1;
#             background-color:  #dcf2d7;
#             color:  #000000;
#         }    #T_f5493588_ae4b_11e9_8512_784f435f5e05row0_col4 {
#             background-color:  #1e0000;
#             color:  #f1f1f1;
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_f5493588_ae4b_11e9_8512_784f435f5e05row0_col5 {
#             background-color:  #f5f5e2;
#             color:  #000000;
#             background-color:  #00682a;
#             color:  #f1f1f1;
#         }    #T_f5493588_ae4b_11e9_8512_784f435f5e05row0_col6 {
#             background-color:  #ffffff;
# ...

# %% [markdown]
# ## 10M

# %%
#SR sell neww
dfs, spoints = mu.get_experiment_info('5d0e9b16d71f100b8a48f460')

# %%
mu.add_colors_and_move(dfs[:20])
# Out:
# <style  type="text/css" >
#     #T_c1596f18_9601_11e9_97c2_784f435f5e05row0_col0 {
#             background-color:  #f0f0ce;
#             color:  #000000;
#             background-color:  #0e7936;
#             color:  #f1f1f1;
#         }    #T_c1596f18_9601_11e9_97c2_784f435f5e05row0_col1 {
#             background-color:  #f2f2d6;
#             color:  #000000;
#             background-color:  #077331;
#             color:  #f1f1f1;
#         }    #T_c1596f18_9601_11e9_97c2_784f435f5e05row0_col2 {
#             background-color:  #e4deae;
#             color:  #000000;
#             background-color:  #2f984f;
#             color:  #000000;
#         }    #T_c1596f18_9601_11e9_97c2_784f435f5e05row0_col3 {
#             background-color:  #f5f5e2;
#             color:  #000000;
#             background-color:  #00682a;
#             color:  #f1f1f1;
#         }    #T_c1596f18_9601_11e9_97c2_784f435f5e05row0_col4 {
#             background-color:  #885757;
# ...

# %% [markdown]
# # V1

# %%
#SR sell
dfs, spoints = mu.get_experiment_info('5ce1cae9d71f1037c0e267c5')

# %%
#SR buy
dfb, bpoints = mu.get_experiment_info('5ce1cafed71f1037c0e267c6')

# %%
mu.add_colors_and_move(dfb[:20])

# %%
mu.add_colors_and_move(dfs.data[:20])
# Out:
# <style  type="text/css" >
#     #T_b416c274_835a_11e9_a73a_784f435f5e05row0_col0 {
#             background-color:  #dccaa3;
#             color:  #000000;
#             background-color:  #45ad5f;
#             color:  #000000;
#         }    #T_b416c274_835a_11e9_a73a_784f435f5e05row0_col1 {
#             background-color:  #f7f7e5;
#             color:  #000000;
#             background-color:  #006428;
#             color:  #f1f1f1;
#         }    #T_b416c274_835a_11e9_a73a_784f435f5e05row0_col2 {
#             background-color:  #d7be9d;
#             color:  #000000;
#             background-color:  #58b668;
#             color:  #000000;
#         }    #T_b416c274_835a_11e9_a73a_784f435f5e05row0_col3 {
#             background-color:  #fafaf0;
#             color:  #000000;
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }    #T_b416c274_835a_11e9_a73a_784f435f5e05row0_col4 {
#             background-color:  #9a6363;
# ...

# %%
df = dfs.data

# %%
df = df[df.index <300]

# %%
mu.add_colors_and_move(df[:20])
# Out:
# <style  type="text/css" >
#     #T_08b3e9ae_835b_11e9_bf49_784f435f5e05row0_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_08b3e9ae_835b_11e9_bf49_784f435f5e05row0_col1 {
#             background-color:  #cda18e;
#             color:  #000000;
#             background-color:  #80ca80;
#             color:  #000000;
#         }    #T_08b3e9ae_835b_11e9_bf49_784f435f5e05row0_col2 {
#             background-color:  #1e0000;
#             color:  #f1f1f1;
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_08b3e9ae_835b_11e9_bf49_784f435f5e05row0_col3 {
#             background-color:  #f8f8e8;
#             color:  #000000;
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }    #T_08b3e9ae_835b_11e9_bf49_784f435f5e05row0_col4 {
#             background-color:  #d7be9d;
# ...

# %%
mu.look_at_deals(spointb, [71, 26])
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# Step 71, sum 42071, mean=18.806884219937416, std=59.44021279512843 deals=2237
# Step 26, sum 12916, mean=26.796680497925312, std=71.77543627865498 deals=482
# Final: sum 9858, mean=34.95744680851064, std=70.7255104393738 deals=282
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
mu.look_at_deals(spoints, [98, 57])
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.font_manager:findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/Users/userid/anaconda3/envs/trading/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# Step 98, sum 25887, mean=57.91275167785235, std=94.47579704434705 deals=447
# Step 57, sum 18181, mean=49.2710027100271, std=85.29040703310235 deals=369
# Final: sum 9475, mean=69.66911764705883, std=79.79381347476328 deals=136
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %% [markdown]
# SELL
# exp: 5d0e9affd71f100b8a48f45d
# Step 98: 5d10b1ca7f1f84d41e961f0b
# Step 57: 5d1072e77f1f84d41e961ee2
#
# BUY
# exp: 5d0e9b05d71f100b8a48f45e
# Step 71: 5d0faf1f7f1f84d41e961e2a
# Step 26: 5d0f70e67f1f84d41e961dfd

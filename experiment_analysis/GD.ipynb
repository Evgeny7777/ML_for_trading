# %% [markdown]
# # Look at GOLD
# ## Current status

# %%
import os; os.chdir('../')
import sys; sys.path.append('.')

# %%
# %config InlineBackend.figure_format = 'retina'
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 1000)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %config InlineBackend.figure_format = 'retina'
from IPython.core.display import display, HTML, Markdown
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline
# Out:
# <style>.container { width:100% !important; }</style>
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
import json
from datetime import datetime, timezone

# %%
from mongoengine.connection import disconnect
from importlib import reload
import py.classes as classes;reload(classes)
import py.mongo as mongo;reload(mongo)
import experiment_analysis.mongo_utils as mu;reload(mu)
disconnect()
db = mongo.connect_to_mongo(db_name='evo_v2')

import logging
l = logging.getLogger("my_logger")
logging.basicConfig(level=logging.DEBUG)
# Out:
# <module 'py.classes' from '/Users/userid/git/evotrade/py/classes.py'>
# <module 'py.mongo' from '/Users/userid/git/evotrade/py/mongo.py'>
# <module 'experiment_analysis.mongo_utils' from '/Users/userid/git/evotrade/experiment_analysis/mongo_utils.py'>

# %%
df = {}
points = {}

# %% [markdown]
# ---

# %% [markdown]
# # V2

# %%
#GZ buy 5M
exp_id = '5d24a12517651b43a8de3bb7'
df[exp_id], points[exp_id] = mu.get_experiment_info(exp_id)

# %%
#GZ sell 5M
exp_id = '5d24a12117651b43a8de3bb6'
df[exp_id], points[exp_id] = mu.get_experiment_info(exp_id)

# %% [markdown]
# ----

# %%
#GD sell 5M
exp_id = '5d24a06d17651b43a8de3bb3'
df[exp_id], points[exp_id] = mu.get_experiment_info(exp_id)

# %%
#GD buy 5M
exp_id = '5d24a07217651b43a8de3bb4'
df[exp_id], points[exp_id] = mu.get_experiment_info(exp_id)

# %% [markdown]
# ---

# %%
exp_id = '5d24a12117651b43a8de3bb6'
mu.add_colors_and_move(df[exp_id].reset_index())
# Out:
# <style  type="text/css" >
#     #T_d27109ee_ae4d_11e9_99d3_9cebe89752a1row0_col0 {
#             background-color:  #e4dfae;
#             color:  #000000;
#             background-color:  #2f974e;
#             color:  #000000;
#         }    #T_d27109ee_ae4d_11e9_99d3_9cebe89752a1row0_col3 {
#             background-color:  #c68c84;
#             color:  #000000;
#             background-color:  #97d492;
#             color:  #000000;
#         }    #T_d27109ee_ae4d_11e9_99d3_9cebe89752a1row0_col4 {
#             background-color:  #9c6565;
#             color:  #000000;
#             background-color:  #cbeac4;
#             color:  #000000;
#         }    #T_d27109ee_ae4d_11e9_99d3_9cebe89752a1row0_col5 {
#             background-color:  #e6e4b1;
#             color:  #000000;
#             background-color:  #29914a;
#             color:  #000000;
#         }    #T_d27109ee_ae4d_11e9_99d3_9cebe89752a1row0_col6 {
#             background-color:  #d4b799;
# ...

# %%
mu.look_at_deals(points[exp_id], [19, 2])
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# Step 19, sum 49320, mean=42.40756663800516, std=108.11355672401123 deals=1163
# Step 2, sum 72293, mean=35.71788537549407, std=138.37782016446783 deals=2024
# Final: sum 20164, mean=52.510416666666664, std=108.72892441057849 deals=384
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %% [markdown]
# ---

# %%
#GD buy
df, points = mu.get_experiment_info('5d0d4f4cd71f100b8a48f450')

# %%
mu.add_colors_and_move(df.reset_index())
# Out:
# <style  type="text/css" >
#     #T_8f339328_9bff_11e9_b422_acde48001122row0_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8f339328_9bff_11e9_b422_acde48001122row0_col3 {
#             background-color:  #5e3a3a;
#             color:  #f1f1f1;
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_8f339328_9bff_11e9_b422_acde48001122row0_col4 {
#             background-color:  #643e3e;
#             color:  #f1f1f1;
#             background-color:  #eaf7e6;
#             color:  #000000;
#         }    #T_8f339328_9bff_11e9_b422_acde48001122row0_col5 {
#             background-color:  #eeeec9;
#             color:  #000000;
#             background-color:  #137d39;
#             color:  #f1f1f1;
#         }    #T_8f339328_9bff_11e9_b422_acde48001122row0_col6 {
#             background-color:  #f7f7e7;
# ...

# %%
#GD buy
df2, points2 = mu.get_experiment_info('5d0c5ea5d71f10e3c068f155')

# %%
mu.add_colors_and_move(df2)
# Out:
# <style  type="text/css" >
#     #T_4e79d2b6_9529_11e9_8657_784f435f5e05row0_col0 {
#             background-color:  #fefefb;
#             color:  #000000;
#             background-color:  #00491d;
#             color:  #f1f1f1;
#         }    #T_4e79d2b6_9529_11e9_8657_784f435f5e05row0_col1 {
#             background-color:  #efefcb;
#             color:  #000000;
#             background-color:  #117b38;
#             color:  #f1f1f1;
#         }    #T_4e79d2b6_9529_11e9_8657_784f435f5e05row0_col2 {
#             background-color:  #eeeec7;
#             color:  #000000;
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }    #T_4e79d2b6_9529_11e9_8657_784f435f5e05row0_col3 {
#             background-color:  #c2817f;
#             color:  #000000;
#             background-color:  #a2d99c;
#             color:  #000000;
#         }    #T_4e79d2b6_9529_11e9_8657_784f435f5e05row0_col4 {
#             background-color:  #623d3d;
# ...

# %% [markdown]
# # __________

# %%
#GD buy
df, points = mu.get_experiment_info('5ce07bcfd71f1037c0e267c3')

# %%
#GD buy gen2
dfb2, b2points = mu.get_experiment_info('5ceb0364d71f1089a856813d')

# %%
#GD buy gen2 try2
dfb22, b22points = get_experiment_info('5cec5445d71f1089a856813e')

# %%
#GD buy
dfs, spoints = get_experiment_info('5ce25c0cd71f1037c0e267c9')

# %%
#GD buy gen2
dfs2, s2points = get_experiment_info('5cea99d0d71f1089a856813b')

# %%
#GD buy gen3
dfs3, s3points = mu.get_experiment_info('5ceb023ed71f1089a856813c')

# %%
#GD sell
dfsreal, srealpoints = mu.get_experiment_info('5cedabb4d71f1089a856813f')

# %%
mu.add_colors_and_move(dfsreal[:20])
# Out:
# <style  type="text/css" >
#     #T_26f90ae2_831d_11e9_8691_784f435f5e05row0_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_26f90ae2_831d_11e9_8691_784f435f5e05row0_col1 {
#             background-color:  #e5e0af;
#             color:  #000000;
#             background-color:  #2d954d;
#             color:  #000000;
#         }    #T_26f90ae2_831d_11e9_8691_784f435f5e05row0_col2 {
#             background-color:  #1e0000;
#             color:  #f1f1f1;
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_26f90ae2_831d_11e9_8691_784f435f5e05row0_col3 {
#             background-color:  #ebebbc;
#             color:  #000000;
#             background-color:  #1e8741;
#             color:  #000000;
#         }    #T_26f90ae2_831d_11e9_8691_784f435f5e05row0_col4 {
#             background-color:  #ffffff;
# ...

# %%
mu.add_colors_and_move(dfb2.data)
# Out:
# <style  type="text/css" >
#     #T_43316dac_80c4_11e9_a193_784f435f5e05row0_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_43316dac_80c4_11e9_a193_784f435f5e05row0_col1 {
#             background-color:  #cb9b8b;
#             color:  #000000;
#             background-color:  #87cd86;
#             color:  #000000;
#         }    #T_43316dac_80c4_11e9_a193_784f435f5e05row0_col2 {
#             background-color:  #ca988a;
#             color:  #000000;
#             background-color:  #8ace88;
#             color:  #000000;
#         }    #T_43316dac_80c4_11e9_a193_784f435f5e05row0_col3 {
#             background-color:  #cda28f;
#             color:  #000000;
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_43316dac_80c4_11e9_a193_784f435f5e05row0_col4 {
#             background-color:  #8f5c5c;
# ...

# %%
mu.add_colors_and_move(df.data)
# Out:
# <style  type="text/css" >
#     #T_f821c2ae_8004_11e9_bb37_784f435f5e05row0_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_f821c2ae_8004_11e9_bb37_784f435f5e05row0_col1 {
#             background-color:  #b97878;
#             color:  #000000;
#             background-color:  #aedea7;
#             color:  #000000;
#         }    #T_f821c2ae_8004_11e9_bb37_784f435f5e05row0_col2 {
#             background-color:  #d3b497;
#             color:  #000000;
#             background-color:  #68be70;
#             color:  #000000;
#         }    #T_f821c2ae_8004_11e9_bb37_784f435f5e05row0_col3 {
#             background-color:  #c68c84;
#             color:  #000000;
#             background-color:  #97d492;
#             color:  #000000;
#         }    #T_f821c2ae_8004_11e9_bb37_784f435f5e05row0_col4 {
#             background-color:  #e6e3b1;
# ...

# %%
mu.add_colors_and_move(dfs3[:20])
# Out:
# <style  type="text/css" >
#     #T_4c3d2d92_808c_11e9_978f_784f435f5e05row0_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_4c3d2d92_808c_11e9_978f_784f435f5e05row0_col1 {
#             background-color:  #dccaa3;
#             color:  #000000;
#             background-color:  #45ad5f;
#             color:  #000000;
#         }    #T_4c3d2d92_808c_11e9_978f_784f435f5e05row0_col2 {
#             background-color:  #e6e3b1;
#             color:  #000000;
#             background-color:  #2a924a;
#             color:  #000000;
#         }    #T_4c3d2d92_808c_11e9_978f_784f435f5e05row0_col3 {
#             background-color:  #ca988a;
#             color:  #000000;
#             background-color:  #8ace88;
#             color:  #000000;
#         }    #T_4c3d2d92_808c_11e9_978f_784f435f5e05row0_col4 {
#             background-color:  #915d5d;
# ...

# %%
mu.add_colors_and_move(dfs2.data[:10])
# Out:
# <style  type="text/css" >
#     #T_80f4eb3a_8003_11e9_8e4d_784f435f5e05row0_col0 {
#             background-color:  #ebebbe;
#             color:  #000000;
#             background-color:  #1c8540;
#             color:  #000000;
#         }    #T_80f4eb3a_8003_11e9_8e4d_784f435f5e05row0_col1 {
#             background-color:  #eeeec9;
#             color:  #000000;
#             background-color:  #137d39;
#             color:  #f1f1f1;
#         }    #T_80f4eb3a_8003_11e9_8e4d_784f435f5e05row0_col2 {
#             background-color:  #573636;
#             color:  #f1f1f1;
#             background-color:  #edf8ea;
#             color:  #000000;
#         }    #T_80f4eb3a_8003_11e9_8e4d_784f435f5e05row0_col3 {
#             background-color:  #f1f1d1;
#             color:  #000000;
#             background-color:  #0b7734;
#             color:  #f1f1f1;
#         }    #T_80f4eb3a_8003_11e9_8e4d_784f435f5e05row0_col4 {
#             background-color:  #9c6565;
# ...

# %% [markdown]
# # V2

# %%
d2 = mu.deals_from_step(points, 2)

# %%
d2.hist('profit')
# Out:
#                      date  profit
# 0     2019-01-04 17:59:00      16
# 1     2019-01-04 18:24:00      -3
# 2     2019-01-04 18:29:00      56
# 3     2019-01-04 19:44:00      -1
# 4     2019-01-08 10:19:00      24
# 5     2019-01-08 11:19:00     -10
# 6     2019-01-08 11:29:00     -12
# 7     2019-01-08 11:59:00     -12
# 8     2019-01-08 17:29:00      17
# 9     2019-01-08 18:04:00      19
# 10    2019-01-08 18:24:00      11
# 11    2019-01-08 18:39:00     -13
# 12    2019-01-08 19:29:00       9
# 13    2019-01-09 10:04:00      35
# 14    2019-01-09 15:34:00     -12
# 15    2019-01-09 16:04:00      46
# 16    2019-01-09 16:59:00      45
# 17    2019-01-09 17:29:00      31
# 18    2019-01-09 18:59:00       3
# 19    2019-01-09 19:29:00      -9
# 20    2019-01-10 23:49:00      -1
# 21    2019-01-11 11:14:00      29
# 22    2019-01-11 12:59:00      -8
# 23    2019-01-11 13:44:00       0
# 24    2019-01-14 11:39:00      13
# 25    2019-01-14 23:49:00      -1
# ...

# %%
mu.look_at_deals(points, df.sort_values(by='vdiff', ascending=False).index[:20])
# Out:
# Step 44, sum 20317, mean=6.224571078431373, std=21.568486942564494 deals=3264
# Step 56, sum 28342, mean=8.265383493729951, std=24.702361842095222 deals=3429
# Step 2, sum 40112, mean=9.263741339491917, std=25.149352019427187 deals=4330
# Step 27, sum 26290, mean=6.980881571959639, std=22.964980693218287 deals=3766
# Step 53, sum 38778, mean=13.91388589881593, std=39.493169748572484 deals=2787
# Step 33, sum 30898, mean=8.511845730027549, std=24.100282992028156 deals=3630
# Step 67, sum 17362, mean=9.113910761154855, std=26.020235755735364 deals=1905
# Step 4, sum 33614, mean=9.901030927835052, std=26.872101240890956 deals=3395
# Step 100, sum 34932, mean=13.482053261289078, std=38.45575563047326 deals=2591
# Step 69, sum 27932, mean=7.352461173993156, std=24.377327487684486 deals=3799
# Step 72, sum 35091, mean=13.236891738966428, std=38.09081121298639 deals=2651
# Step 91, sum 34391, mean=13.545096494682946, std=35.855016181324274 deals=2539
# ...

# %% [markdown]
# -------

# %%
d4 = deals_from_step(b22points, 4)

# %%
d19 = deals_from_step(b2points, 19)
d32 = deals_from_step(b2points, 32)

# %%
mu.look_at_deals(b22points, [4, 62])
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# Step 4, sum 302.3999999999994, mean=2.3624999999999954, std=2.756695499822238 deals=128
# Step 62, sum 211.89999999999964, mean=3.3109374999999943, std=3.219342197795691 deals=64
# Final: sum 211.0, mean=4.137254901960785, std=3.020924413772296 deals=51
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
mu.look_at_deals(b2points, [19, 32])
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# Step 19, sum 280.00000000000136, mean=2.522522522522535, std=2.9029666545131674 deals=111
# Step 32, sum 177.89999999999986, mean=2.9649999999999976, std=2.8385258169618908 deals=60
# Final: sum 214.70000000000027, mean=3.3546875000000043, std=3.19830955784111 deals=64
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
mu.look_at_deals(s2points, [217, 223])
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# Step 217, sum 340.19999999999936, shape=181
# Step 223, sum 307.7000000000005, shape=195
# Overall sum=320.40000000000055, min=-5.100000000000136, deals=143
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
look_at_deals(spoints, [48])
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# Step 48, sum 254.00000000000045, shape=84
# Overall sum=254.00000000000045, min=-3.599999999999909, deals=84
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
